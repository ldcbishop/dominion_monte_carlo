# %%
import random

class card:
    # Pseudo singleton representations of different cards
    
    
    def __init__(self, p_val, m_val, c_val, name = ''):
        self.p_val = p_val
        self.m_val = m_val
        self.c_val = c_val
        self.name = name
        
    def givePoints(self):
        return self.p_val
    
    def giveMoney(self):
        return self.m_val
    
    def giveCost(self):
        return self.c_val
    
    def sayName(self):
        return name
    
class deck:
    cards = list()
    discard = list()
    
    def newDeck(self, autoload = True):
        if autoload:
            # Add copper
            for i in range(7):
                # Append default copper key
                pass
            for i in range(3):
                # Load default estate key
                
    def addCard(self, new_card):
        # New card should be an integer that references into the card library, which is a dict
        self.cards.append(new_card)
        
    def drawCard(self):
        return self.cards.pop()
    
    def discardCard(self, card):
        self.discard.append(card)
        
    def shuffle(self):
        self.cards = random.sample(discard)
        self.discard = []
        
    # Diagnostic methods
    def valueInDeck(self, category, board = None):
        
        assert(board != None)
        
        if category = 'm':
            method = giveMoney()
        elif cateogry = 'p':
            method = givePoints()
        elif cateogry = 'c':
            method = giveCost()
        
        this_sum = 0
        for i in cards:
            this_sum += board[i].method()
        
        return this_sum
